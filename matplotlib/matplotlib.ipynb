# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
print(np.__version__)
print(matplotlib.__version__)
print(pd.__version__)
# Out:
# 1.19.2
# 3.3.2
# 1.1.3

# %% [markdown]
# #### Basic Graph

# %%
x = [1, 2, 3]
y = [1, 2, 3]
# y = [2, 4, 6]

plt.plot(x, y, label='1:1',
        color='green',
        linestyle='dashed',
        marker='o', ## marks the actual cross point of (x, y)
        )

nums = np.arange(1, 10, 0.1)
plt.plot(nums, np.sin(nums), label='sin')

plt.title('First pyplot', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

plt.xlabel('Time', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 16})
plt.ylabel('Distance', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 16})

# plt.xticks(list(range(1, 4)))
# plt.yticks(list(range(1, 4)))


plt.legend()  # requires lebel to be present

plt.show()

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# ### Bar chart

# %%
labels = ['A', 'B', 'C']
values = [1, 4, 2]

bars = plt.bar(labels, values)

bars[0].set_hatch('/')
bars[1].set_hatch('o')

plt.figure(figsize=(8, 4))

plt.show()

# %%
import time
plt.plot([0, 0], [0, 1], 'g-', marker='o',)

AB = ([0, 2], [0, 1])

initial_tan_theta = np.rad2deg(np.arctan([AB[1][1]/AB[0][1]])) # oop/adj  -- 1/2

hypot = np.hypot(1, 2)  # perpendicular, base

for n in np.arange(initial_tan_theta, 365, 5):
    
    rad = np.deg2rad(n)
    opp_side, base = (np.sin(rad) * hypot), (np.cos(rad) * hypot)
    
    plt.plot([0, base], [0, opp_side], 'g-', marker='o',)
#     time.sleep(0.1)

plt.show()

# %%
t = np.array([[1, 2], [1,2]])
t.shape
# Out:
# (2, 2)

# %%
print(np.angle([2, 1]))
print(np.angle([2, 1], deg=True))
# Out:
# [0. 0.]
# [0. 0.]

# %%
np.arctan([0.5, 1, 0])
# Out:
# array([0.46364761, 0.78539816, 0.        ])

# %%
np.tan([0, 1, 0.5])
# Out:
# array([0.        , 1.55740772, 0.54630249])

# %%
from math import pi

print(np.sin([pi/6]))

print(np.arcsin([0.5]) / pi)

print(np.arcsin([0.5]) * pi)

print(np.arcsin([0.5]))
# Out:
# [0.5]
# [0.16666667]
# [1.64493407]
# [0.52359878]

# %%
np.sin(np.pi/6)
# Out:
# 0.49999999999999994

# %%
np.arcsin(0.5) * 52
# Out:
# 27.227136331111545

# %%
np.sin([np.deg2rad(90)])
# Out:
# array([1.])

# %%
import time
plt.plot([0, 0], [0, 1], 'g-', marker='o',)

AB = ([0, 2], [0, 1])

initial_tan_theta = np.rad2deg(np.arctan([AB[1][1]/AB[0][1]])) # oop/adj  -- 1/2

hypot = np.hypot(1, 2)  # perpendicular, base

for n in np.arange(initial_tan_theta, 95, 5):
    
    rad = np.deg2rad(n)
    opp_side, base = (np.sin(rad) * hypot), (np.cos(rad) * hypot)
#     print(opp_side, base)
    opp_side, base = np.dot([[1, 2]], [[np.cos(rad), -np.sin(rad)], [np.sin(rad), np.cos(rad)]])[0]
    
    plt.plot([0, base], [0, opp_side], 'g-', marker='o',)
#     time.sleep(0.1)

plt.show()
